# %%
pip install Flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask, request, jsonify
import pickle
import joblib

# %%
import pickle
from keras.models import load_model

# Load your model (assuming you have it in .h5 format)
traffic_model = load_model('C:/Users/pc/PycharmProjects/Final Project/models/traffic_lstm.h5')

# Save the model using pickle
with open('C:/Users/pc/PycharmProjects/Final Project/models/traffic_lstm.pkl', 'wb') as file:
    pickle.dump(traffic_model, file)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import joblib

# Load the model
accident_model = joblib.load('C:/Users/pc/PycharmProjects/Final Project/accident.pkl')

# %%
from flask import Flask, request, jsonify
import tensorflow as tf
import numpy as np

# %%
app = Flask(__name__)

# %%
accident_model
# Out:
# <Sequential name=sequential, built=True>

# %%
traffic_model
# Out:
# <Sequential name=sequential, built=True>

# %%
def predict(model, input_data):
    # Convert input_data to tensor
    input_tensor = tf.convert_to_tensor(input_data, dtype=tf.float32)
    # Run prediction
    predictions = model(input_tensor)
    return predictions.numpy().tolist()

# %%
@app.route('/predict_accident', methods=['POST'])
def predict_accident():
    data = request.json
    input_data = np.array(data['input'])  # Ensure input data is in array format
    predictions = predict(accident_model, input_data)
    return jsonify(predictions)

# %%
@app.route('/predict_traffic', methods=['POST'])
def predict_traffic():
    data = request.json
    input_data = np.array(data['input'])  # Ensure input data is in array format
    predictions = predict(traffic_lstm_model, input_data)
    return jsonify(predictions)

# %%
if __name__ == '__main__':
    app.run(debug=True, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [09/Sep/2024 11:56:16] "GET / HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [09/Sep/2024 11:56:16] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [09/Sep/2024 11:56:31] "GET / HTTP/1.1" 404 -
