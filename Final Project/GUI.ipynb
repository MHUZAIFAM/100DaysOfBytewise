# %%
import tkinter as tk
from tkinter import messagebox
import joblib
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
# Load your saved model
model = joblib.load('accident.pkl')
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\saving\saving_lib.py:713: UserWarning: Skipping variable loading for optimizer 'adam', because it has 22 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# Create the main window
root = tk.Tk()
root.title("Accident Severity Predictor")
# Out:
# ''

# %%
labels = ['Temperature (F)', 'Visibility (mi)', 'Hour', 'Day of Week']
entries = []

# %%
for label in labels:
    tk.Label(root, text=label).pack()
    entry = tk.Entry(root)
    entry.pack()
    entries.append(entry)

# Define the prediction function
def predict_severity():
    try:
        # Retrieve and convert input data
        inputs = [float(entry.get()) for entry in entries]
        # Scale the inputs
        inputs_scaled = scaler.transform([inputs])
        # Make a prediction
        prediction = model.predict(inputs_scaled)
        # Display the result
        messagebox.showinfo("Prediction", f"Predicted Severity: {prediction[0]}")
    except Exception as e:
        messagebox.showerror("Error", f"Invalid input: {e}")

# Add a button to trigger the prediction
predict_button = tk.Button(root, text="Predict Severity", command=predict_severity)
predict_button.pack()

# Run the GUI loop
root.mainloop()
